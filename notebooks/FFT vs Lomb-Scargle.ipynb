# %%
import numpy as np
x = np.linspace(0., 1., 200)
y = np.sin(50 * 2 * np.pi *  x)
plt.plot(x, y)
plt.show()

# %%
from scipy import fft
yf = fft(y)
xf = np.linspace(0, len(x)//2, len(x)//2)
plt.plot(xf, np.abs(yf[:len(x)//2]))
plt.show()

# %%
frequency, power = LombScargle(x,y).autopower()
plt.plot(frequency[:500], power[:500])
plt.show()
