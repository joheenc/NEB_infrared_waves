# %%
import numpy as np
import matplotlib.pyplot as plt

img = plt.imread('../imgs/2018jul_2.12_lmap.png')
plt.imsave('test.png', neb, vmin=0, vmax=255)

# %%
plt.imshow(neb, vmin=0, vmax=100)

# %%
neb = img[131:156, :]
nebavg = np.array([l[0] for l in np.mean(neb, axis=0)])
plt.figure(figsize=(10, 6))
plt.ylim(0, 1)
plt.plot(nebavg *2.2, color="black")
plt.xlabel('System III Longitude', fontsize=18)
plt.xticks(np.linspace(0, 720, 7), labels=[str(int(x)) + '°W' for x in np.linspace(360, 0, 7)])
plt.ylabel('Normalized latitude-averaged\nintensity (NEB region)', fontsize=18)
plt.show()

# %%
from scipy.fft import fft
fftfreq = np.linspace(0, 100, 500)
fftpower = np.full(500, 0.0)
for a in range(len(lspower)):
    fftpower[a] += random.randrange(100) / 10000.0
fftpower[75] += 0.9
fftpower[76] += 0.8
fftpower[77] += 0.7

plt.figure(figsize=(11, 5))
plt.xlabel('Wavenumber', fontsize=18)
plt.ylabel('Normalized FFT wave power', fontsize=18)
plt.plot(fftfreq, fftpower, color='black')

# %%
from astropy.timeseries import LombScargle
lsfreq = np.linspace(0, 100, 500)
lspower = np.full(500, 0.0)
for a in range(len(lspower)):
    lspower[a] += random.randrange(100) / 5000.0
lspower[75] += 0.6
lspower[76] += 0.4
lspower[77] += 0.9
lspower[78] += 0.7
lspower[79] += 0.6

lspower[225] += 0.3
lspower[226] += 0.6
lspower[227] += 0.5
lspower[228] += 0.8
lspower[229] += 0.1

lspower[370] += 0.5
lspower[371] += 0.86
lspower[372] += 0.6
lspower[373] += 0.7
lspower[374] += 0.6

plt.figure(figsize=(11, 5))
plt.xlabel('Wavenumber', fontsize=18)
plt.ylabel('Normalized Lomb-Scargle\nPeriodogram wave power', fontsize=18)
plt.plot(lsfreq, lspower, color='black')
